# %%
"C:\Users\ply58\OneDrive\Tài liệu\PythonML\Github Repositories\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\hearing_test.csv"

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ply58\\OneDrive\\Tài liệu\\PythonML\\Github Repositories\\UNZIP_FOR_NOTEBOOKS_FINAL\\DATA\\hearing_test.csv")

# %%
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
df.describe()
# Out:
#                age  physical_score  test_result
# count  5000.000000     5000.000000  5000.000000
# mean     51.609000       32.760260     0.600000
# std      11.287001        8.169802     0.489947
# min      18.000000       -0.000000     0.000000
# 25%      43.000000       26.700000     0.000000
# 50%      51.000000       35.300000     1.000000
# 75%      60.000000       38.900000     1.000000
# max      90.000000       50.000000     1.000000

# %%
df['test_result'].value_counts().plot(kind='bar', color=['red', 'green'])
# Out:
# <Axes: xlabel='test_result'>

# %%
plt.figure(dpi=100)
sns.boxplot(x='test_result', y='age', data=df, palette="Set2")
# Out:
# C:\Users\ply58\AppData\Local\Temp\ipykernel_61220\1425170100.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='test_result', y='age', data=df, palette="Set2")
# <Axes: xlabel='test_result', ylabel='age'>

# %%
plt.figure(dpi=100)
sns.boxplot(x='test_result', y='physical_score', data=df, palette="Set1")
# Out:
# C:\Users\ply58\AppData\Local\Temp\ipykernel_61220\1035616345.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='test_result', y='physical_score', data=df, palette="Set1")
# <Axes: xlabel='test_result', ylabel='physical_score'>

# %%
sns.scatterplot(x='age', y='physical_score', hue='test_result', data=df, palette="Set1")
# Out:
# <Axes: xlabel='age', ylabel='physical_score'>

# %%
sns.pairplot(df, hue='test_result', palette="Set1", diag_kind='kde', markers=["o", "s"])

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
sns.scatterplot(x='physical_score', y='test_result', data=df, hue='test_result', palette="Set2")
# Out:
# <Axes: xlabel='physical_score', ylabel='test_result'>

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['age'], df['physical_score'], df['test_result'], c=df['test_result'])
