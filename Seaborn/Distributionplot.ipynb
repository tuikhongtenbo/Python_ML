# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\ply58\\PythonML\\UNZIP_FOR_NOTEBOOKS_FINAL\\05-Seaborn\\dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(5, 5), dpi=100)
sns.rugplot(x='salary', data=df, height=0.25)
# Out:
# <Axes: xlabel='salary'>

# %%
plt.figure(figsize=(7, 5), dpi=100)
sns.set(style='darkgrid')
sns.histplot(data=df, x='salary', bins=50, color='purple', ec='yellow', lw=10, ls='--')
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
plt.figure(figsize=(7, 5), dpi=100)
sns.set(style='darkgrid')
sns.displot(data=df, x='sales', bins=30, color='green', ec='red', lw=20, ls='--', kde=True, rug=True)

# %%
sns.kdeplot(data=df, x='sales')
# Out:
# <Axes: xlabel='sales', ylabel='Density'>

# %%
np.random.seed(42)
sample_ages = np.random.randint(0, 100, 2000)
sample_ages = pd.DataFrame(sample_ages, columns=['age'])

# %%
sns.set(style='ticks')
sns.displot(data=sample_ages, x='age', rug=True, kde=True, bins=60)

# %%
sns.kdeplot(data=sample_ages, x='age', clip=[20, 50], bw_adjust=0.1, shade=True, color='orange')
# Out:
# C:\Users\ply58\AppData\Local\Temp\ipykernel_12912\450936159.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=sample_ages, x='age', clip=[20, 50], bw_adjust=0.1, shade=True, color='orange')
# <Axes: xlabel='age', ylabel='Density'>
