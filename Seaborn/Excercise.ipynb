# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ply58\\PythonML\\UNZIP_FOR_NOTEBOOKS_FINAL\\05-Seaborn\\application_record.csv")

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
employed = df[df['DAYS_EMPLOYED']<0]

# %%
employed['DAYS_EMPLOYED'] = employed['DAYS_EMPLOYED'] *-1
employed['DAYS_BIRTH'] = employed['DAYS_BIRTH'] *-1

# %%
plt.figure(figsize=(8, 5), dpi=150)
sns.scatterplot(data=employed, x='DAYS_BIRTH', y='DAYS_EMPLOYED', alpha=0.002)
# Out:
# <Axes: xlabel='DAYS_BIRTH', ylabel='DAYS_EMPLOYED'>

# %%
plt.figure(figsize=(6, 3), dpi=100)
df['YEAR']=(-1)*df['DAYS_BIRTH']/365
sns.histplot(data=df, x='YEAR', bins=50, color='pink')
# Out:
# <Axes: xlabel='YEAR', ylabel='Count'>

# %%
df = pd.read_csv("C:\\Users\\ply58\\PythonML\\UNZIP_FOR_NOTEBOOKS_FINAL\\05-Seaborn\\application_record.csv")

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
len(df)/2
# Out:
# 219278.5

# %%
income_total = df.nsmallest(n=219278, columns='AMT_INCOME_TOTAL')

# %%
plt.figure(figsize=(8, 3), dpi=100)
sns.boxplot(data=income_total, x='NAME_FAMILY_STATUS', y='AMT_INCOME_TOTAL', hue='FLAG_OWN_REALTY')
plt.legend(bbox_to_anchor=(1.15, 0.8), title='FLAG_OWN_REALTY')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df=df[df['OCCUPATION_TYPE'].notnull()]

# %%
df
# Out:
#              ID  AMT_INCOME_TOTAL    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 2       5008806          112500.0               Married  House / apartment
# 3       5008808          270000.0  Single / not married  House / apartment
# 4       5008809          270000.0  Single / not married  House / apartment
# 5       5008810          270000.0  Single / not married  House / apartment
# 6       5008811          270000.0  Single / not married  House / apartment
# ...         ...               ...                   ...                ...
# 438541  6837707          202500.0        Civil marriage  House / apartment
# 438548  6839936          135000.0               Married  House / apartment
# 438553  6840222          103500.0  Single / not married  House / apartment
# 438554  6841878           54000.0  Single / not married       With parents
# 438556  6842885          121500.0               Married  House / apartment
#
# ...

# %%
df=df.drop(columns='CODE_GENDER')
df=df.drop(columns='FLAG_OWN_CAR')
df=df.drop(columns='FLAG_OWN_REALTY')
df=df.drop(columns='CNT_CHILDREN')
df=df.drop(columns='NAME_INCOME_TYPE')
df=df.drop(columns='NAME_EDUCATION_TYPE')
df=df.drop(columns='NAME_FAMILY_TYPE')
df=df.drop(columns='NAME_HOUSING_TYPE')
df=df.drop(columns='OCCUPATION_TYPE')
df=df.drop(columns='NAME_FAMILY_STATUS')
df=df.drop(columns='NAME_HOUSING_TYPE')
df=df.drop(columns='OCCUPATION_TYPE')
df=df.drop(columns='FLAG_MOBIL')

# %%
correlation=df.corr()

# %%
plt.figure(dpi=150)
sns.heatmap(data=correlation, cmap='viridis', annot=True)
# Out:
# <Axes: >
