# %%
# !git clone https://github.com/tuikhongtenbo/Python_ML.git
# Out:
# Cloning into 'Python_ML'...
# remote: Enumerating objects: 968, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 968 (delta 31), reused 21 (delta 19), pack-reused 929 (from 1)
# Receiving objects: 100% (968/968), 149.46 MiB | 30.57 MiB/s, done.
# Resolving deltas: 100% (418/418), done.
# Updating files: 100% (215/215), done.

# %%
# %cd /kaggle/working/Python_ML/BaitapDS201/TH3
# Out:
# /kaggle/working/Python_ML/BaitapDS201/TH3

# %%
# !python main.py --config lstm \
    --lr 0.001 \
    --epochs 30 \
    --batch_size 64 \
    --embedding_dim 256 \
    --hidden_size 256 \
    --num_layers 5 \
    --dropout 0.2
# Out:
# [Override] Learning rate: 0.001
# [Override] Num epochs: 30
# [Override] Batch size: 64
# [Override] Embedding dim: 256
# [Override] Hidden size: 256
# [Override] Num layers: 5
# [Override] Dropout: 0.2
# Loading data...
# Vocabulary size: 2488
# Number of classes: 3
# Label mapping: {'negative': 0, 'neutral': 1, 'positive': 2}
#
# Model architecture:
#   Model: LSTM
#   Embedding dim: 256
#   Hidden size: 256
#   Number of layers: 5
#   Dropout: 0.2
#   Number of classes: 3
#   Total parameters: 3,400,963
# 2025-11-27 12:37:02,864 - lstm_trainer - INFO - Starting training for 30 epochs
# 2025-11-27 12:37:02,865 - lstm_trainer - INFO - Device: cuda
# 2025-11-27 12:37:02,865 - lstm_trainer - INFO - Model parameters: 3,400,963
# 2025-11-27 12:37:02,865 - lstm_trainer - INFO -
# Epoch 1/30
# ...
# Evaluating: 100%|███████████████████████████████| 25/25 [00:00<00:00, 32.06it/s]
# 2025-11-27 12:37:17,312 - lstm_trainer - INFO - Train Loss: 0.7330
# ...

# %%
# !python main.py --config gru \
    --lr 0.001 \
    --epochs 30 \
    --batch_size 32 \
    --embedding_dim 256 \
    --hidden_size 256 \
    --num_layers 5 \
    --dropout 0.2
# Out:
# [Override] Learning rate: 0.001
# [Override] Num epochs: 30
# [Override] Batch size: 32
# [Override] Embedding dim: 256
# [Override] Hidden size: 256
# [Override] Num layers: 5
# [Override] Dropout: 0.2
# Loading data...
# Vocabulary size: 2488
# Number of classes: 3
# Label mapping: {'negative': 0, 'neutral': 1, 'positive': 2}
#
# Model architecture:
#   Model: GRU
#   Embedding dim: 256
#   Hidden size: 256
#   Number of layers: 5
#   Dropout: 0.2
#   Number of classes: 3
#   Total parameters: 2,743,043
# 2025-11-27 12:26:21,155 - lstm_trainer - INFO - Starting training for 30 epochs
# 2025-11-27 12:26:21,155 - lstm_trainer - INFO - Device: cuda
# 2025-11-27 12:26:21,155 - lstm_trainer - INFO - Model parameters: 2,743,043
# 2025-11-27 12:26:21,155 - lstm_trainer - INFO -
# Epoch 1/30
# ...
# Evaluating: 100%|███████████████████████████████| 50/50 [00:00<00:00, 55.73it/s]
# 2025-11-27 12:26:40,179 - lstm_trainer - INFO - Train Loss: 0.6999
# ...

# %%
# !python main.py --config encoder \
    --lr 0.001 \
    --epochs 30 \
    --batch_size 64 \
    --embedding_dim 256 \
    --hidden_size 256 \
    --num_layers 5 \
    --dropout 0.2
# Out:
# [Override] Learning rate: 0.001
# [Override] Num epochs: 30
# [Override] Batch size: 32
# [Override] Embedding dim: 256
# [Override] Hidden size: 256
# [Override] Num layers: 5
# [Override] Dropout: 0.2
# Loading data...
# Vocabulary size: 4350
# Number of tags: 20
# Tag mapping: {'B-AGE': 1, 'B-DATE': 2, 'B-GENDER': 3, 'B-JOB': 4, 'B-LOCATION': 5, 'B-NAME': 6, 'B-ORGANIZATION': 7, 'B-PATIENT_ID': 8, 'B-SYMPTOM_AND_DISEASE': 9, 'B-TRANSPORTATION': 10, 'I-AGE': 11, 'I-DATE': 12, 'I-JOB': 13, 'I-LOCATION': 14, 'I-NAME': 15, 'I-ORGANIZATION': 16, 'I-PATIENT_ID': 17, 'I-SYMPTOM_AND_DISEASE': 18, 'I-TRANSPORTATION': 19, 'O': 20}
#
# Model architecture:
#   Model: Encoder (BiLSTM)
#   Embedding dim: 256
#   Hidden size: 256
#   Number of BiLSTM layers: 5
#   Dropout: 0.2
#   Number of tags (including padding): 21
#   Number of actual tags: 20
#   Total parameters: 8,484,885
# 2025-11-27 12:14:37,951 - ner_trainer - INFO - Starting training for 30 epochs
# ...
