# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\ply58\\PythonML\\UNZIP_FOR_NOTEBOOKS_FINAL\\DATA\\mpg.csv")

# %%
data
del data['name']
df = pd.DataFrame(data=data, columns=data.columns)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
# Data Preprocessing
df.replace('?', np.nan, inplace=True)
df = df.dropna()

# Vẽ:
fig, axes = plt.subplots(4, 2, figsize=(16, 20))
fig.tight_layout(pad=5.0)

axes = axes.flatten()

# 1
sns.histplot(data=df, x="mpg", bins=10, kde=True, ax=axes[0])
axes[0].set_title("Histogram of MPG")

# 2
sns.scatterplot(data=df, x="weight", y="mpg", hue="cylinders", palette="viridis", ax=axes[1])
axes[1].set_title("Scatterplot of Weight vs MPG")

# 3
sns.boxplot(data=data, x="origin", y="mpg", palette="Set2", ax=axes[2])
axes[2].set_title("Boxplot: MPG by Origin")
axes[2].set_xlabel("Origin")
axes[2].set_ylabel("MPG")

# 4
sns.lineplot(data=df, x="model_year", y="mpg", marker="o", ax=axes[3])
axes[3].set_title("Lineplot of MPG over Model Year")

# 5
sns.barplot(data=df, x="cylinders", y="displacement", palette="muted", ax=axes[4])
axes[4].set_title("Barplot of Displacement by Cylinders")

#6
sns.violinplot(data=df, x="origin", y="acceleration", hue="origin", split=True, ax=axes[5])
axes[5].set_title("Violin Plot of Acceleration by Origin")

# 7
axes[6].plot(df.index, df["mpg"], label="MPG", color="blue", linestyle="-")
axes[6].plot(df.index, df["acceleration"], label="Acceleration", color="green", ls="-")
axes[6].plot(df.index, df["displacement"], label="Displacement", color="red", ls="-")
axes[6].set_title("Line Chart: MPG, Acceleration, Displacement")
axes[6].set_xlabel("Index")
axes[6].set_ylabel("Values")
axes[6].legend()
axes[6].grid(True)

fig.delaxes(axes[7])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ply58\AppData\Local\Temp\ipykernel_18636\1842039659.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="origin", y="mpg", palette="Set2", ax=axes[2])
# C:\Users\ply58\AppData\Local\Temp\ipykernel_18636\1842039659.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="cylinders", y="displacement", palette="muted", ax=axes[4])
