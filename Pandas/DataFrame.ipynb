# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0, 101, (4, 3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]], dtype=int32)

# %%
myindex = ['CA', 'NY', 'AZ', 'TX']

# %%
mycolumns = ['Jan', 'Wed', 'Mar']

# %%
df = pd.DataFrame(mydata)

# %%
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data = mydata, index = myindex, columns = mycolumns)

# %%
df
# Out:
#     Jan  Wed  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is C206-ECC0
#
#  Directory of C:\Users\ply58\PythonML\Pandas
#
# 09/09/2024  02:06 PM    <DIR>          .
# 09/04/2024  09:07 PM    <DIR>          ..
# 09/06/2024  05:11 PM    <DIR>          .ipynb_checkpoints
# 09/09/2024  02:06 PM            16,058 DataFrame.ipynb
# 09/06/2024  11:16 AM           731,403 Series.ipynb
#                2 File(s)        747,461 bytes
#                3 Dir(s)  380,289,818,624 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\ply58\\PythonML\\Pandas'

# %%
pd.read_csv('C:\\Users\\ply58\\Downloads\\SampleCSVFile_119kb.csv', encoding='latin1')
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 3       5                           Holmes HEPA Air Purifier
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
df.columns
# Out:
# Index(['Jan', 'Wed', 'Mar'], dtype='object')

# %%
df.index
# Out:
# Index(['CA', 'NY', 'AZ', 'TX'], dtype='object')

# %%
df = pd.read_csv('C:\\Users\\ply58\\Downloads\\SampleCSVFile_119kb.csv', encoding='latin1')

# %%
df.columns
# Out:
# Index(['1', 'Eldon Base for stackable storage shelf, platinum',
#        'Muhammed MacIntyre', '3', '-213.25', '38.94', '35', 'Nunavut',
#        'Storage & Organization', '0.8'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=999, step=1)

# %%
df.head(10)
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
# 9  11                                         Xerox 1980    Neola Schneider
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# ...

# %%
df.tail(11)
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 988   990    Advantus Map Pennant Flags and Round Head Tacks
# 989   991  Office Star - Mid Back Dual function Ergonomic...
# 990   992  Belkin 107-key enhanced keyboard, USB/PS/2 int...
# 991   993                                               5185
# 992   994     Hon Every-Day® Chair Series Swivel Task Chairs
# 993   995                                          Avery 494
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 988        Seth Vernon  44199    -6.33    3.95   2.00  British Columbia
# 989         Alex Avila  44231   116.10  160.98  30.00  British Columbia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   1                                                 999 non-null    int64
#  1   Eldon Base for stackable storage shelf, platinum  999 non-null    object
#  2   Muhammed MacIntyre                                999 non-null    object
#  3   3                                                 999 non-null    int64
#  4   -213.25                                           999 non-null    float64
#  5   38.94                                             999 non-null    float64
#  6   35                                                999 non-null    float64
#  7   Nunavut                                           999 non-null    object
#  8   Storage & Organization                            999 non-null    object
# ...

# %%
df.describe()
# Out:
#                  1             3       -213.25        38.94          35  \
# count   999.000000    999.000000    999.000000   999.000000  999.000000
# mean    501.000000  29194.111111    166.504424    86.739079   13.454585
# std     288.530761  17155.729763   1033.870113   206.287133   17.929233
# min       2.000000     35.000000 -11053.600000     1.260000    0.490000
# 25%     251.500000  14373.500000    -86.650000     6.810000    3.300000
# 50%     501.000000  28802.000000      1.320000    22.980000    6.260000
# 75%     750.500000  43378.000000    161.305000    99.990000   14.480000
# max    1000.000000  59750.000000  10951.310000  3499.990000  147.120000
#
#               0.8
# count  989.000000
# mean     0.516047
# std      0.136451
# min      0.350000
# 25%      0.380000
# 50%      0.540000
# 75%      0.590000
# max      0.850000

# %%
df.describe().transpose()
# Out:
#          count          mean           std       min       25%       50%  \
# 1        999.0    501.000000    288.530761      2.00    251.50    501.00
# 3        999.0  29194.111111  17155.729763     35.00  14373.50  28802.00
# -213.25  999.0    166.504424   1033.870113 -11053.60    -86.65      1.32
# 38.94    999.0     86.739079    206.287133      1.26      6.81     22.98
# 35       999.0     13.454585     17.929233      0.49      3.30      6.26
# 0.8      989.0      0.516047      0.136451      0.35      0.38      0.54
#
#                75%       max
# 1          750.500   1000.00
# 3        43378.000  59750.00
# -213.25    161.305  10951.31
# 38.94       99.990   3499.99
# 35          14.480    147.12
# 0.8          0.590      0.85

# %%
df['Muhammed MacIntyre']
# Out:
# 0           Barry French
# 1           Barry French
# 2          Clay Rozendal
# 3         Carlos Soltero
# 4         Carlos Soltero
#              ...
# 994        Dennis Bolton
# 995    Anthony O'Donnell
# 996       Barbara Fisher
# 997       Barbara Fisher
# 998       Barbara Fisher
# Name: Muhammed MacIntyre, Length: 999, dtype: object

# %%
mycols = ['Muhammed MacIntyre', '35']
df[mycols]
# Out:
#     Muhammed MacIntyre     35
# 0         Barry French  68.02
# 1         Barry French   2.99
# 2        Clay Rozendal   3.99
# 3       Carlos Soltero   5.94
# 4       Carlos Soltero   4.95
# ..                 ...    ...
# 994      Dennis Bolton   9.54
# 995  Anthony O'Donnell  14.45
# 996     Barbara Fisher   1.99
# 997     Barbara Fisher   6.67
# 998     Barbara Fisher   9.03
#
# [999 rows x 2 columns]

# %%
df['3'] + df['35']
# Out:
# 0        361.02
# 1        295.99
# 2        486.99
# 3        520.94
# 4        519.95
#          ...
# 994    48174.54
# 995    48211.45
# 996    48485.99
# 997    48490.67
# 998    48493.03
# Length: 999, dtype: float64

# %%
10 * df['3'] / df['35']
# Out:
# 0          43.075566
# 1         979.933110
# 2        1210.526316
# 3         867.003367
# 4        1040.404040
#            ...
# 994     50487.421384
# 995     33354.325260
# 996    243638.190955
# 997     72689.655172
# 998     53692.137320
# Length: 999, dtype: float64

# %%
df['Adding col'] = 10 * df['3'] / df['35']

# %%
df.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8  \
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
#
#     Adding col
# 0    43.075566
# ...

# %%
df['Adding col'] = np.round(10 * df['3'] / df['35'], 2)

# %%
df.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8  \
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
#
#    Adding col
# 0       43.08
# 1      979.93
# ...

# %%
df.drop('Adding col', axis=1)
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 3       5                           Holmes HEPA Air Purifier
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
df.head(1000)
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 3       5                           Holmes HEPA Air Purifier
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
df.set_index("Eldon Base for stackable storage shelf, platinum")
# Out:
#                                                        1 Muhammed MacIntyre  \
# Eldon Base for stackable storage shelf, platinum
# 1.7 Cubic Foot Compact "Cube" Office Refrigerators     2       Barry French
# Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       3       Barry French
# R380                                                   4      Clay Rozendal
# Holmes HEPA Air Purifier                               5     Carlos Soltero
# G.E. Longer-Life Indoor Recessed Floodlight Bulbs      6     Carlos Soltero
# ...                                                  ...                ...
# Xerox 1905                                           996      Dennis Bolton
# Dana Halogen Swing-Arm Architect Lamp                997  Anthony O'Donnell
# Maxell DVD-RAM Discs                                 998     Barbara Fisher
# DAX Contemporary Wood Frame with Silver Metal M...   999     Barbara Fisher
# Computer Printout Paper with Letter-Trim Perfor...  1000     Barbara Fisher
#
# ...

# %%
df.reset_index()
# Out:
#      index     1   Eldon Base for stackable storage shelf, platinum  \
# 0        0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1        1     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2        2     4                                               R380
# 3        3     5                           Holmes HEPA Air Purifier
# 4        4     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..     ...   ...                                                ...
# 994    994   996                                         Xerox 1905
# 995    995   997              Dana Halogen Swing-Arm Architect Lamp
# 996    996   998                               Maxell DVD-RAM Discs
# 997    997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998    998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# ...

# %%
df.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8  \
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
#
#    Adding col
# 0       43.08
# 1      979.93
# ...

# %%
df.iloc[0]
# Out:
# 1                                                                                                   2
# Eldon Base for stackable storage shelf, platinum    1.7 Cubic Foot Compact "Cube" Office Refrigera...
# Muhammed MacIntyre                                                                       Barry French
# 3                                                                                                 293
# -213.25                                                                                        457.81
# 38.94                                                                                          208.16
# 35                                                                                              68.02
# Nunavut                                                                                       Nunavut
# Storage & Organization                                                                     Appliances
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=999, step=1)

# %%
df.loc[[3, 4, 5, 6]]
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5  7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6  8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
#
#      3  -213.25  38.94    35  Nunavut          Storage & Organization   0.8  \
# 3  515    30.94  21.78  5.94  Nunavut                      Appliances  0.50
# 4  515     4.43   6.64  4.95  Nunavut              Office Furnishings  0.37
# 5  613   -54.04   7.30  7.72  Nunavut  Binders and Binder Accessories  0.38
# 6  613   127.70  42.76  6.22  Nunavut          Storage & Organization   NaN
#
#    Adding col
# 3      867.00
# 4     1040.40
# 5      794.04
# 6      985.53

# %%
df.drop(3, axis = 0)
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 5       7  Angle-D Binders with Locking Rings, Label Holders
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3  -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.81  208.16  68.02           Nunavut
# 1         Barry French    293    46.71    8.69   2.99           Nunavut
# ...

# %%
df.head()
# Out:
#    1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0  2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1  3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2  4                                               R380      Clay Rozendal
# 3  5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4  6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8  \
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 1  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 2  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 3  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 4  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
#
#    Adding col
# 0       43.08
# 1      979.93
# ...

# %%
one_row = df.loc[3]

# %%
df = pd.concat([df, one_row])

# %%
df
# Out:
#                           1  \
# 0                       2.0
# 1                       3.0
# 2                       4.0
# 3                       5.0
# 4                       6.0
# ...                     ...
# 35                      NaN
# Nunavut                 NaN
# Storage & Organization  NaN
# 0.8                     NaN
# Adding col              NaN
#
#                          Eldon Base for stackable storage shelf, platinum  \
# 0                       1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1                        Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2                                                                    R380
# 3                                                Holmes HEPA Air Purifier
# 4                       G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ...                                                                   ...
# 35                                                                    NaN
# ...
